# %% [markdown]
# <a href="https://colab.research.google.com/github/iamalihasn/python_code/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("Enter a number : "))

if number & 1 != 0:
  print("Odd")
else:
  print("Even")
# Out:
# Enter a number : 11
# Odd

# %%
print("Hello")
# Out:
# Hello
